# %% [markdown]
# <h1>Word2Vec</h1>

# %%
! pip install gensim

# %%
import numpy as np
import pandas as pd
import gensim
import os

# %%
! pip install --upgrade gensim --user

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/ngocson/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
story = []
data_path = 'data'
for filename in os.listdir(path=data_path):
    if filename == '.txt':
        pass
    f = open(os.path.join(data_path, filename), encoding='utf-8', errors='ignore')
    print(f)
    corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))
# Out:
# <_io.TextIOWrapper name='data/002ssb.txt' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='data/005ssb.txt' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='data/test.txt' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='data/003ssb.txt' mode='r' encoding='utf-8'>
# <_io.TextIOWrapper name='data/004ssb.txt' mode='r' encoding='utf-8'>

# %%
story
# Out:
# [['clash',
#   'of',
#   'kings',
#   'book',
#   'two',
#   'of',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'by',
#   'george',
#   'martin',
#   'prologue',
#   'the',
#   'comet',
#   'tail',
#   'spread',
#   'across',
#   'the',
#   'dawn',
#   'red',
#   'slash',
#   'that',
#   'bled',
#   'above',
#   'the',
#   'crags',
#   'of',
#   'dragonstone',
#   'like',
#   'wound',
#   'in',
#   'the',
#   'pink',
#   'and',
#   'purple',
#   'sky'],
#  ['the',
#   'maester',
#   'stood',
#   'on',
#   'the',
#   'windswept',
#   'balcony',
#   'outside',
#   'his',
#   'chambers'],
#  ['it', 'was', 'here', 'the', 'ravens', 'came', 'after', 'long', 'flight'],
#  ['their',
#   'droppings',
#   'speckled',
#   'the',
#   'gargoyles',
#   'that',
#   'rose',
#   'twelve',
#   'feet',
#   'tall',
#   'on',
#   'either',
#   'side',
#   'of',
#   'him',
#   'hellhound',
#   'and',
#   'wyvern',
#   'two',
#   'of',
#   'the',
#   'thousand',
#   'that',
#   'brooded',
# ...

# %%
story = []
data_path = 'data/test.txt'
f = open(os.path.join(data_path))
corpus = f.read()
raw_sent = sent_tokenize(corpus)
for sent in raw_sent:
    story.append(simple_preprocess(sent))

# %%
story
# Out:
# [['game',
#   'of',
#   'thrones',
#   'book',
#   'one',
#   'of',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'by',
#   'george',
#   'martin',
#   'prologue',
#   'we',
#   'should',
#   'start',
#   'back',
#   'gared',
#   'urged',
#   'as',
#   'the',
#   'woods',
#   'began',
#   'to',
#   'grow',
#   'dark',
#   'around',
#   'them'],
#  ['the', 'wildlings', 'are', 'dead'],
#  ['do', 'the', 'dead', 'frighten', 'you'],
#  ['ser',
#   'waymar',
#   'royce',
#   'asked',
#   'with',
#   'just',
#   'the',
#   'hint',
#   'of',
#   'smile'],
#  ['gared', 'did', 'not', 'rise', 'to', 'the', 'bait'],
#  ['he',
#   'was',
#   'an',
#   'old',
#   'man',
#   'past',
#   'fifty',
#   'and',
#   'he',
#   'had',
#   'seen',
#   'the',
#   'lordlings',
#   'come',
#   'and',
#   'go'],
#  ['dead', 'is', 'dead', 'he', 'said'],
#  ['we', 'have', 'no', 'business', 'with', 'the', 'dead'],
#  ['are', 'they', 'dead'],
#  ['royce', 'asked', 'softly'],
# ...

# %%
story[0]
# Out:
# ['game',
#  'of',
#  'thrones',
#  'book',
#  'one',
#  'of',
#  'song',
#  'of',
#  'ice',
#  'and',
#  'fire',
#  'by',
#  'george',
#  'martin',
#  'prologue',
#  'we',
#  'should',
#  'start',
#  'back',
#  'gared',
#  'urged',
#  'as',
#  'the',
#  'woods',
#  'began',
#  'to',
#  'grow',
#  'dark',
#  'around',
#  'them']

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2,
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)

model.wv.most_similar('daenerys')
# Out:
# [('tarly', 0.9966214895248413),
#  ('blows', 0.9963544011116028),
#  ('marillion', 0.9960699677467346),
#  ('qotho', 0.9959839582443237),
#  ('samwell', 0.9959742426872253),
#  ('eating', 0.9959092736244202),
#  ('mycah', 0.9957959651947021),
#  ('pyp', 0.9955273270606995),
#  ('morrec', 0.9954410195350647),
#  ('tomard', 0.9952903389930725)]

# %%
model.wv.similarity('arya', 'sansa')
# Out:
# 0.97450185

# %%
model.wv['deep'].shape
# Out:
# (100,)

# %%
vec = model.wv.get_normed_vectors()
vec
# Out:
# array([[-0.07702277,  0.00493675,  0.02358964, ..., -0.16649191,
#         -0.02572059,  0.14468235],
#        [-0.01810896,  0.08563656,  0.01286781, ..., -0.2275475 ,
#          0.06616662,  0.06084759],
#        [-0.18367735,  0.02508773,  0.0383669 , ..., -0.03825743,
#          0.02992877, -0.16783129],
#        ...,
#        [-0.01617179, -0.04094031,  0.04156227, ..., -0.18118283,
#          0.05520927, -0.08061925],
#        [-0.01785086,  0.05172336,  0.03477435, ..., -0.16427323,
#         -0.00343984, -0.00463825],
#        [-0.0252588 ,  0.13132644,  0.00450837, ..., -0.16198678,
#          0.04886888, -0.06333404]], dtype=float32)

# %%
y=model.wv.index_to_key

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
X = pca.fit_transform(model.wv.get_normed_vectors())
X
# Out:
# array([[-0.3562734 ,  0.24045461,  0.3260905 ],
#        [-0.45939803,  0.08598101,  0.17958413],
#        [ 0.42677587,  0.15171719,  0.0030885 ],
#        ...,
#        [ 0.04691252,  0.10065973, -0.2451028 ],
#        [-0.35615134,  0.02163994,  0.23419046],
#        [-0.16186357, -0.04764265,  0.02998102]], dtype=float32)

# %%
X.shape
# Out:
# (7432, 3)

# %%
! pip install plotly

# %%
! pip install nbformat

# %%
! pip install nbformat --upgrade

# %%
import pandas as pd
import plotly.express as px

# Giả sử X có 3 cột: x, y, z
df = pd.DataFrame(X[200:300], columns=['x', 'y', 'z'])

# Thêm nhãn color từ y
df['label'] = y[200:300]

# Vẽ scatter 3D
fig = px.scatter_3d(
    data_frame=df,
    x='x',
    y='y',
    z='z',
    color='label'
)
fig.show()
